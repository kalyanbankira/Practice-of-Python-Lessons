# %%
import pandas as pd
sr = pd.Series(['Naveen', 'Rahul', 'Sarah', 'Nitin', 'Neha'])
result = sr.str.contains(pat = 'N[a-e]')
result
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ---
