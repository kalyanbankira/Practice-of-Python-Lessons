# %%
import pandas as pd
import numpy as np

A = ['Cold', 'Hot', 'Warm', 'Cold', 'Cold', 'Warm']
B = ['High', 'High', 'Medium', 'Medium', 'High', 'Low']
C = ['Pleasent', 'Hot', 'Hot', 'Pleasent', 'Pleasent', np.nan]

# Complete the code and select correct output.
# Make a dataframe
df = pd.DataFrame({"Temperature":A, "Humidity":B, "C":C})

# Convert categorical column to numerical one.
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

for column in df.columns:
  df[column] = label.fit_transform(df[column])

# TCalculate euclidean distance between each data point.
from sklearn.metrics.pairwise import nan_euclidean_distances

dist = nan_euclidean_distances(df, df)
dist_df = pd.DataFrame(dist)
dist_df
# Out:
#           0         1         2         3         4         5
# 0  0.000000  1.414214  3.000000  2.000000  0.000000  2.449490
# 1  1.414214  0.000000  2.236068  2.449490  1.414214  2.449490
# 2  3.000000  2.236068  0.000000  2.236068  3.000000  2.236068
# 3  2.000000  2.449490  2.236068  0.000000  2.000000  2.449490
# 4  0.000000  1.414214  3.000000  2.000000  0.000000  2.449490
# 5  2.449490  2.449490  2.236068  2.449490  2.449490  0.000000
