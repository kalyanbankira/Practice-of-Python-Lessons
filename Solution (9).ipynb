# %%
1. # importing required libraries
import pandas as pd
import random
from sklearn.decomposition import PCA

A = [57, 81, 58, 30, 63, 70, 78, 44, 89, 69]
B = [21, 12, 132, 138, 85, 139, 176, 41, 76, 67]
C = [196, 220, 6, 92, 446, 313, 218, 139, 89, 112]
D = [243, 238, 202, 298, 44, 197, 246, 217, 272, 207]
E = [187, 64, 24, 46, 280, 288, 265, 270, 165, 106]

# Complete the code and select correct output.
# Make a dataframe
df = pd.DataFrame({"A":A, "B":B, "C":C,"D":D, "E":E})

# performing preprocessing part (StandardScaler)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaled_df = sc.fit_transform(df)

# PCA
pca = PCA(n_components = 2)
pca_value = pca.fit_transform(scaled_df)
print(pca_value[:5])
# Out:
# [[-0.12322167  0.82558609]
#  [-0.35972282  1.93387446]
#  [-1.66490886 -0.62032887]
#  [-2.21270111 -1.6041741 ]
#  [ 3.37686202 -0.24574157]]
