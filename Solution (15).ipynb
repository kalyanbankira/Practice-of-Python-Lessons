# %%
12 % 5
# Out:
# 2

# %%
10/2
# Out:
# 5.0

# %%
odd = []

for i in range(0,1001):
    if (i % 2) != 0 and (i % 3) != 2 and (i % 4) == 3 and (i % 5) != 0 and (i % 5) != 2 and (i % 7) != 0:
        odd.append(i)
print(odd)


print(len(odd))
# Out:
# [3, 19, 31, 39, 43, 51, 79, 99, 103, 111, 123, 139, 151, 159, 163, 171, 183, 199, 211, 219, 223, 243, 271, 279, 283, 291, 303, 319, 331, 339, 351, 363, 379, 391, 403, 411, 423, 439, 451, 459, 463, 471, 499, 519, 523, 531, 543, 559, 571, 579, 583, 591, 603, 619, 631, 639, 643, 663, 691, 699, 703, 711, 723, 739, 751, 759, 771, 783, 799, 811, 823, 831, 843, 859, 871, 879, 883, 891, 919, 939, 943, 951, 963, 979, 991, 999]
# 86

# %%
# Import libraries
import pandas as pd

# Make a DataFrame
df = pd.DataFrame({'A': [0, 1, 2, 9, 4],
                   'B': [4, 9, 2, 0, 3],
                   'C': [8, 2, 7, 6, 8]})

# Perform the rolling window calculations with window size = 2
df.rolling(2).sum()
# Out:
#       A     B     C
# 0   NaN   NaN   NaN
# 1   1.0  13.0  10.0
# 2   3.0  11.0   9.0
# 3  11.0   2.0  13.0
# 4  13.0   3.0  14.0
