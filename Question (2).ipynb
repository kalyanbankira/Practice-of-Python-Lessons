# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

import warnings
warnings.filterwarnings("ignore")

# Make a DataFrame
time = pd.date_range(start = '1999-01-01', end = '1999-01-31', freq='D')
prices = [130, 142, 142, 161, 169, 193, 206, 249, 271, 289, 301, 313,
          315, 322, 327, 332, 342, 345, 349, 354, 370, 382, 426, 434,
          442, 445, 462, 466, 472, 496, 498]
price_df = pd.DataFrame({'Days': time, 'Price': prices})

# Set the 'Days' column as index of the DataFrame.
price_ind = price_df.set_index('Days')
# Build ARIMA model using entire dataset.
# Set p = 1, d = 1, q = 0

arima_model = ARIMA(price_df,order = (1,1,0)).fit()
# Predict using `predict()` and print first 5 observations
pred = arima_model.predict(1,len(price_df)-2)
pred.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0a97a9b33ae6> in <cell line: 22>()
#      20 # Set p = 1, d = 1, q = 0
#      21
# ---> 22 arima_model = ARIMA(price_df,order = (1,1,0)).fit()
#      23 # Predict using `predict()` and print first 5 observations
#      24 pred = arima_model.predict(1,len(price_df)-2)
#
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/arima/model.py in __init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     151         # this criteria. Instead, we'll just make sure that the parameter
#     152         # estimates from those methods satisfy the criteria.)
# --> 153         self._spec_arima = SARIMAXSpecification(
# ...
