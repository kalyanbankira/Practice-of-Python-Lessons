# %%
word = "green vegetables"
print(word.find('g',2))
# Out:
# 8

# %%
print(word.find('veg',2))
# Out:
# 6

# %%
print(word.find('tab',4,15))
# Out:
# 10

# %%
num = 25
def compute():
    num = 20
    print(num,end=' ')

compute()
print(num)
# Out:
# 20 25

# %%
def compute(x, y):
    return str(x) +
str(len(y))
m = compute(25,
    'mycstutorial')
print(m)
# Out:
#   File "<ipython-input-6-97c6ac572937>", line 2
#     return str(x) +
#                    ^
# SyntaxError: invalid syntax
